# %%
56 +78
# Out:
# 134

# %%
56 + 78.0
# Out:
# 134.0

# %%
"字串" + 56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 "字串" + 56
#
# TypeError: can only concatenate str (not "int") to str

# %%
(3*4, 6/2, 7//3, 7%3, 7**3)
# Out:
# (12, 3.0, 2, 1, 343)

# %%
2*(1+2)**2 - 2**2*2
# Out:
# 10

# %%
"2*(1+2)**2 - 2**2*2"
# Out:
# '2*(1+2)**2 - 2**2*2'

# %%
eval("2*(1+2)**2 - 2**2*2")
# Out:
# 10

# %%
print ("abc")
"abc"
# Out:
# abc
# 'abc'
# Bad pipe message: %s [b'\x82\x05"\xb6\xaf\x11>`\x10\x8b@?\x95~\r\xc3\xd6\xd2 N\x8e\xec3\xe7\x16\xac\x01\x16\xfc8+\xe4\x95\xce\xbf"B)\xfe\xa0\x05\x9eB\xdcFZ79|j\xd9\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \xc3\x1a\x0f\x96*\xed\x1a\n\xa7o\xaf#\x15\xce']
# Bad pipe message: %s [b'`\x84=Q\xd2\x0e\xa9\x7f\xdf\x8c\x8a\xf8\xe83\rW\x84\x1d \x08\xb9"']
# ...

# %%
n =5
n+10
n
# Out:
# 5

# %%
n=5
n+=10
n*=10
n
# Out:
# 150

# %%
n=5
m=10

print(f"n + m = {n+m}")
# Out:
# n + m = 15

# %%
n=5
m=10

print(f"{n} + {m} = {n+m}")
# Out:
# 5 + 10 = 15
